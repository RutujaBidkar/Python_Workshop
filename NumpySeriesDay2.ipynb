# %% [markdown]
# <a href="https://colab.research.google.com/github/RutujaBidkar/Python_Workshop/blob/main/NumpySeriesDay2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

a = np.array([10, 20, 30, 40, 50])

# %%
print(a[2])
# Out:
# 30

# %%
print(a[0])
# Out:
# 10

# %%
print(a[4])
# Out:
# 50

# %%
a = np.array([5, 10, 15, 20, 25, 30])
print(a[0])
print(a[3])
print(a[5])
# Out:
# 5
# 20
# 30

# %%
print(a[-1])
# Out:
# 30

# %%
print(a[:3])
# Out:
# [ 5 10 15]

# %%
#Find the correct start and stop values.
print(a[0:5])
# Out:
# [ 5 10 15 20 25]

# %%
a = np.array([10, 20, 30, 40, 50, 60])
print(a[0:5:2])
# Out:
# [10 30 50]

# %%
#reverse the array
print(a[::-1])
# Out:
# [60 50 40 30 20 10]

# %%
a = np.array([[1,2,3],
             [4,5,6]])
print(a)
a
# Out:
# [[1 2 3]
#  [4 5 6]]
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
print(a[1,1])
# Out:
# 5

# %%
print(a[0:1])
# Out:
# [[1 2 3]]

# %%
a[:0]
# Out:
# array([], shape=(0, 3), dtype=int64)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1233/1685329121.py in <cell line: 0>()
# ----> 1 print(dtype(a))
#
# NameError: name 'dtype' is not defined
