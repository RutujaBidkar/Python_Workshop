# %% [markdown]
# <a href="https://colab.research.google.com/github/RutujaBidkar/Python_Workshop/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import pandas
import pandas as pd

# %%
#Creates pandas series
data = [10,20,30,40,50]

# %%
s = pd.Series(data)
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
#Create a Series with Custom Index
s = pd.Series(
    [80,90,85],
index = ["Maths","Physics","chemistry"]
)
print(s)
# Out:
# Maths        80
# Physics      90
# chemistry    85
# dtype: int64

# %%
#Create a DataFrame
data = {
    "Name" : ["Rutuja" ,"Kunal","kunalvis"],
    " age" : [23,25,30],
    "Salary": [500000,450000,480000]

    }

df = pd.DataFrame(data)
print(df)
# Out:
#        Name   age  Salary
# 0    Rutuja    23  500000
# 1     Kunal    25  450000
# 2  kunalvis    30  480000

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data = [10,20,30,40,50]
data
# Out:
# [10, 20, 30, 40, 50]

# %%
#Create a Series with custom indexes:
r = pd.Series (
    [70,80,90],
index = ["Pyhsics","Maths","chemistry"]
)
r
# Out:
# Pyhsics      70
# Maths        80
# chemistry    90
# dtype: int64

# %%
#Create a DataFrame with these columns:
data = {
    "Name" : ["Rutuja", "Pallavi", "Rutu"],
    "Age"  : [23,24,23],
    "City" :["Pune","Kholapur","Solapur"]

}
df = pd.DataFrame(data)
df
# Out:
#       Name  Age      City
# 0   Rutuja   23      Pune
# 1  Pallavi   24  Kholapur
# 2     Rutu   23   Solapur
